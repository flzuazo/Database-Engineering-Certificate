# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
Data Science Tools and Libraries

This notebook provides an overview of essential tools, libraries, and languages in data science.

## Data Science Languages
1. Python
2. R
3. SQL

## Data Science Libraries
1. Pandas
2. NumPy
3. Scikit-learn
4. TensorFlow


## Data Science Tools
| Tool           | Description                     |
|----------------|---------------------------------|
| Jupyter Notebook | Interactive coding environment |
| RStudio          | IDE for R                      |
| GitHub           | Code hosting platform          |

## Arithmetic Expression Examples
Below are some examples of basic arithmetic operations, including multiplication and addition.

# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
hours

## Objectives
- List popular data science languages
- List commonly used libraries
- Present essential data science tools
- Demonstrate Python arithmetic operations

## Objectives
This notebook covers the following key objectives:
- Understand data science languages and libraries
- Explore tools commonly used in data science
- Practice arithmetic operations in Python
- Demonstrate basic data conversion techniques

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
